# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# Import API key"
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
print(cities)
# Out:
# ['la ronge', 'port alfred', 'busselton', 'hithadhoo', 'margate', 'qaanaaq', 'jamestown', 'sentyabrskiy', 'antofagasta', 'torbay', 'tiksi', 'namibe', 'mahebourg', 'cacapava do sul', 'gamboula', 'barentsburg', 'bac lieu', 'rikitea', 'batagay', 'hobart', 'itupiranga', 'tsihombe', 'hermanus', 'saint-philippe', 'ibipeba', 'luderitz', 'nova londrina', 'illoqqortoormiut', 'bredasdorp', 'souillac', 'leningradskiy', 'kruisfontein', 'minab', 'yulara', 'ushuaia', 'san quintin', 'ilulissat', 'dudinka', 'flensburg', 'barra patuca', 'barrow', 'kefamenanu', 'le port', 'jacareacanga', 'mrirt', 'puerto ayora', 'karratha', 'sassandra', 'saskylakh', 'albany', 'cabo san lucas', 'tekirdag', 'rocha', 'sinnamary', 'havoysund', 'bosaso', 'dikson', 'castro', 'coquimbo', 'atuona', 'punta arenas', 'harper', 'naugarzan', 'attawapiskat', 'tatawin', 'tessalit', 'mahaicony', 'zolotinka', 'hilo', 'kapaa', 'georgetown', 'belushya guba', 'kodiak', 'vila franca do campo', 'san vicente', 'touros', 'bethel', 'almunecar', 'beloha', 'naryan-mar', 'lebu', 'chuy', 'ponta do sol', 'fortuna', 'avarua', 'ampanihy', 'svetlaya', 'palmer', 'carnarvon', 'toliary', 'mataura', 'sioux lookout', 'houma', 'kysyl-syr', 'myaundzha', 'kaitangata', 'norman wells', 'yellowknife', 'ternate', 'yavatmal', 'la grande', 'new norfolk', 'chokurdakh', 'fort saint john', 'lompoc', 'ulladulla', 'armacao dos buzios', 'mpongwe', 'shache', 'port blair', 'khandyga', 'jiwani', 'kutum', 'grand river south east', 'honiara', 'adrar', 'thompson', 'bluff', 'waingapu', 'mana', 'nizhneyansk', 'provideniya', 'chongwe', 'namatanai', 'saldanha', 'bonfim', 'veracruz', 'nantucket', 'iqaluit', 'salalah', 'druzhba', 'rapid valley', 'saint george', 'butaritari', 'cape town', 'pangnirtung', 'flin flon', 'clyde river', 'victoria', 'grand centre', 'ixtapa', 'bereznik', 'hami', 'egvekinot', 'gimli', 'vaini', 'lasa', 'abha', 'tasiilaq', 'blyznyuky', 'tsnori', 'portknockie', 'geraldton', 'hasaki', 'nikolskoye', 'lisakovsk', 'prieska', 'moyale', 'colares', 'achisay', 'payakumbuh', 'kiruna', 'hobyo', 'tuktoyaktuk', 'fort nelson', 'taolanaro', 'sao joao da barra', 'chagoda', 'mar del plata', 'nguiu', 'pochutla', 'meulaboh', 'olinda', 'aklavik', 'chapais', 'umzimvubu', 'yanan', 'rio gallegos', 'maloy', 'vilyuysk', 'ndele', 'falmouth', 'jiangyou', 'sola', 'nicoya', 'edgewater', 'arraial do cabo', 'lawan kuda baharu', 'port elizabeth', 'villarrica', 'dali', 'east london', 'dakoro', 'matara', 'rawson', 'dicabisagan', 'esqueda', 'port moresby', 'nanortalik', 'gazojak', 'belaya gora', 'banda aceh', 'virovitica', 'roma', 'sangueya', 'darhan', 'sinkat', 'coari', 'san policarpo', 'kaniama', 'esperance', 'poopo', 'filadelfia', 'upernavik', 'bingol', 'la cruz', 'hamilton', 'komsomolets', 'airai', 'taltal', 'caravelas', 'khanpur', 'bintulu', 'bria', 'bathsheba', 'mitsamiouli', 'mogadishu', 'westport', 'necochea', 'kiunga', 'pictou', 'bichura', 'saint-joseph', 'fort frances', 'almirante', 'khatanga', 'hualmay', 'vaitupu', 'kandrian', 'agadez', 'soyo', 'komsomolskiy', 'nurota', 'saint-paul', 'whitehorse', 'bambous virieux', 'alyangula', 'narsaq', 'asfi', 'koslan', 'terney', 'te anau', 'goderich', 'dalbandin', 'guatire', 'yermish', 'vila velha', 'kangaatsiaq', 'algeciras', 'broken hill', 'vao', 'san andres', 'richards bay', 'camamu', 'srednekolymsk', 'boyolangu', 'jimeta', 'wahran', 'harlingen', 'sungaipenuh', 'saint-leu', 'teknaf', 'vicuna', 'trebukhiv', 'tabialan', 'gari', 'tocopilla', 'acapulco', 'kamenskoye', 'sol-iletsk', 'youkounkoun', 'talcahuano', 'leshukonskoye', 'tigil', 'weligama', 'praia', 'san patricio', 'miri', 'sao filipe', 'narasannapeta', 'zyryanka', 'gazanjyk', 'agirish', 'akdepe', 'kroya', 'ancud', 'pisco', 'natitingou', 'burnie', 'lira', 'ambon', 'bengkulu', 'amderma', 'paamiut', 'iglino', 'tarudant', 'kidodi', 'mount isa', 'faanui', 'marystown', 'hagi', 'jega', 'peruibe', 'lebanon', 'sinegorye', 'katsuura', 'los llanos de aridane', 'tura', 'chicama', 'clermont', 'yenagoa', 'tombouctou', 'meyungs', 'longyearbyen', 'w ...

# %%
#test = ['hi how', 'are', 'you', 'i am', 'fine', 'thank you', 'for', 'asking']
for index, city in enumerate(cities):
    cities[index] = city.replace(' ', '+')
print(cities)
# Out:
# ['la+ronge', 'port+alfred', 'busselton', 'hithadhoo', 'margate', 'qaanaaq', 'jamestown', 'sentyabrskiy', 'antofagasta', 'torbay', 'tiksi', 'namibe', 'mahebourg', 'cacapava+do+sul', 'gamboula', 'barentsburg', 'bac+lieu', 'rikitea', 'batagay', 'hobart', 'itupiranga', 'tsihombe', 'hermanus', 'saint-philippe', 'ibipeba', 'luderitz', 'nova+londrina', 'illoqqortoormiut', 'bredasdorp', 'souillac', 'leningradskiy', 'kruisfontein', 'minab', 'yulara', 'ushuaia', 'san+quintin', 'ilulissat', 'dudinka', 'flensburg', 'barra+patuca', 'barrow', 'kefamenanu', 'le+port', 'jacareacanga', 'mrirt', 'puerto+ayora', 'karratha', 'sassandra', 'saskylakh', 'albany', 'cabo+san+lucas', 'tekirdag', 'rocha', 'sinnamary', 'havoysund', 'bosaso', 'dikson', 'castro', 'coquimbo', 'atuona', 'punta+arenas', 'harper', 'naugarzan', 'attawapiskat', 'tatawin', 'tessalit', 'mahaicony', 'zolotinka', 'hilo', 'kapaa', 'georgetown', 'belushya+guba', 'kodiak', 'vila+franca+do+campo', 'san+vicente', 'touros', 'bethel', 'almunecar', 'beloha', 'naryan-mar', 'lebu', 'chuy', 'ponta+do+sol', 'fortuna', 'avarua', 'ampanihy', 'svetlaya', 'palmer', 'carnarvon', 'toliary', 'mataura', 'sioux+lookout', 'houma', 'kysyl-syr', 'myaundzha', 'kaitangata', 'norman+wells', 'yellowknife', 'ternate', 'yavatmal', 'la+grande', 'new+norfolk', 'chokurdakh', 'fort+saint+john', 'lompoc', 'ulladulla', 'armacao+dos+buzios', 'mpongwe', 'shache', 'port+blair', 'khandyga', 'jiwani', 'kutum', 'grand+river+south+east', 'honiara', 'adrar', 'thompson', 'bluff', 'waingapu', 'mana', 'nizhneyansk', 'provideniya', 'chongwe', 'namatanai', 'saldanha', 'bonfim', 'veracruz', 'nantucket', 'iqaluit', 'salalah', 'druzhba', 'rapid+valley', 'saint+george', 'butaritari', 'cape+town', 'pangnirtung', 'flin+flon', 'clyde+river', 'victoria', 'grand+centre', 'ixtapa', 'bereznik', 'hami', 'egvekinot', 'gimli', 'vaini', 'lasa', 'abha', 'tasiilaq', 'blyznyuky', 'tsnori', 'portknockie', 'geraldton', 'hasaki', 'nikolskoye', 'lisakovsk', 'prieska', 'moyale', 'colares', 'achisay', 'payakumbuh', 'kiruna', 'hobyo', 'tuktoyaktuk', 'fort+nelson', 'taolanaro', 'sao+joao+da+barra', 'chagoda', 'mar+del+plata', 'nguiu', 'pochutla', 'meulaboh', 'olinda', 'aklavik', 'chapais', 'umzimvubu', 'yanan', 'rio+gallegos', 'maloy', 'vilyuysk', 'ndele', 'falmouth', 'jiangyou', 'sola', 'nicoya', 'edgewater', 'arraial+do+cabo', 'lawan+kuda+baharu', 'port+elizabeth', 'villarrica', 'dali', 'east+london', 'dakoro', 'matara', 'rawson', 'dicabisagan', 'esqueda', 'port+moresby', 'nanortalik', 'gazojak', 'belaya+gora', 'banda+aceh', 'virovitica', 'roma', 'sangueya', 'darhan', 'sinkat', 'coari', 'san+policarpo', 'kaniama', 'esperance', 'poopo', 'filadelfia', 'upernavik', 'bingol', 'la+cruz', 'hamilton', 'komsomolets', 'airai', 'taltal', 'caravelas', 'khanpur', 'bintulu', 'bria', 'bathsheba', 'mitsamiouli', 'mogadishu', 'westport', 'necochea', 'kiunga', 'pictou', 'bichura', 'saint-joseph', 'fort+frances', 'almirante', 'khatanga', 'hualmay', 'vaitupu', 'kandrian', 'agadez', 'soyo', 'komsomolskiy', 'nurota', 'saint-paul', 'whitehorse', 'bambous+virieux', 'alyangula', 'narsaq', 'asfi', 'koslan', 'terney', 'te+anau', 'goderich', 'dalbandin', 'guatire', 'yermish', 'vila+velha', 'kangaatsiaq', 'algeciras', 'broken+hill', 'vao', 'san+andres', 'richards+bay', 'camamu', 'srednekolymsk', 'boyolangu', 'jimeta', 'wahran', 'harlingen', 'sungaipenuh', 'saint-leu', 'teknaf', 'vicuna', 'trebukhiv', 'tabialan', 'gari', 'tocopilla', 'acapulco', 'kamenskoye', 'sol-iletsk', 'youkounkoun', 'talcahuano', 'leshukonskoye', 'tigil', 'weligama', 'praia', 'san+patricio', 'miri', 'sao+filipe', 'narasannapeta', 'zyryanka', 'gazanjyk', 'agirish', 'akdepe', 'kroya', 'ancud', 'pisco', 'natitingou', 'burnie', 'lira', 'ambon', 'bengkulu', 'amderma', 'paamiut', 'iglino', 'tarudant', 'kidodi', 'mount+isa', 'faanui', 'marystown', 'hagi', 'jega', 'peruibe', 'lebanon', 'sinegorye', 'katsuura', 'los+llanos+de+aridane', 'tura', 'chicama', 'clermont', 'yenagoa', 'tombouctou', 'meyungs', 'longyearbyen', 'w ...

# %% [markdown]
# ## Perform API Calls

# %%
# Starting URL for Weather Map API Call
query_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key + "&q="

print(query_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=

# %%
test = requests.get(query_url + 'turlock').json()
print(json.dumps(test, sort_keys=True, indent=4))
# Out:
# {
#     "base": "stations",
#     "clouds": {
#         "all": 1
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 37.49,
#         "lon": -120.85
#     },
#     "dt": 1533534900,
#     "id": 5404024,
#     "main": {
#         "humidity": 36,
#         "pressure": 1012,
#         "temp": 74.57,
#         "temp_max": 75.2,
#         "temp_min": 73.4
#     },
#     "name": "Turlock",
#     "sys": {
#         "country": "US",
#         "id": 427,
#         "message": 0.0039,
#         "sunrise": 1533561125,
#         "sunset": 1533611149,
#         "type": 1
#     },
#     "visibility": 16093,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 320,
#         "speed": 6.93
#     }
# }

# %%
# set up lists to hold reponse info
used_cities = []
lats = []
temp = []
humidity = []
cloudiness = []
wind_speed = []

count = 1
# Loop through the list of cities and perform a request for data on each
for city in cities:
    
    try:
        response = requests.get(query_url + city).json()
        #print(json.dumps(response, indent=4,sort_keys=True))
        temp.append(response['main']['temp'])
        lats.append(response['coord']['lat'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        print(f'Processing record #{count} | City: {city}')
        print(query_url + city)
        used_cities.append(city)
        count += 1
    except Exception as e:
        print(f'Weather data not found for {city}...skipping.')
        print(f'Error raised: {e}')
        cities.remove(city)

print("\n-------------------------")
print("Data retrieval complete!")
print("-------------------------")

#print(f"The latitude information received is: {lats}")
#print(f"The temperature information received is: {temp}")
#print(f"The humidity information received is: {humidity}")
#print(f"The cloudiness information received is: {cloudiness}")
#print(f"The wind speed (mph) information received is: {wind_speed}")
# Out:
# Processing record #1 | City: la+ronge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=la+ronge
# Processing record #2 | City: port+alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=port+alfred
# Processing record #3 | City: busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=busselton
# Processing record #4 | City: hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=hithadhoo
# Processing record #5 | City: margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=margate
# Processing record #6 | City: qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=qaanaaq
# Processing record #7 | City: jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=jamestown
# Weather data not found for sentyabrskiy...skipping.
# Error raised: 'main'
# Processing record #8 | City: torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=torbay
# Processing record #9 | City: tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=tiksi
# Processing record #10 | City: namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=namibe
# Processing record #11 | City: mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=mahebourg
# Processing record #12 | City: cacapava+do+sul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=cacapava+do+sul
# Processing record #13 | City: gamboula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=gamboula
# Weather data not found for barentsburg...skipping.
# Error raised: 'main'
# Processing record #14 | City: rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=rikitea
# Processing record #15 | City: batagay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=batagay
# Processing record #16 | City: hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=hobart
# Processing record #17 | City: itupiranga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=itupiranga
# Weather data not found for tsihombe...skipping.
# Error raised: 'main'
# Processing record #18 | City: saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=saint-philippe
# Processing record #19 | City: ibipeba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ibipeba
# Processing record #20 | City: luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=luderitz
# Processing record #21 | City: nova+londrina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=nova+londrina
# Weather data not found for illoqqortoormiut...skipping.
# Error raised: 'main'
# Processing record #22 | City: souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=souillac
# Processing record #23 | City: leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=leningradskiy
# Processing record #24 | City: kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kruisfontein
# Processing record #25 | City: minab
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=minab
# Processing record #26 | City: yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=yulara
# Processing record #27 | City: ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ushuaia
# Processing record #28 | City: san+quintin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=san+quintin
# Processing record #29 | City: ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ilulissat
# Processing record #30 | City: dudinka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=dudinka
# Processing record #31 | City: flensburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=flensburg
# Processing record #32 | City: barra+patuca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=barra+patuca
# Processing record #33 | City: barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=barrow
# Processing record #34 | City: kefamenanu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kefamenanu
# Processing record #35 | City: le+port
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=le+port
# Processing record #36 | City: jacareacanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=jacareacanga
# Weather data not found for mrirt...skipping.
# Error raised: 'main'
# Processing record #37 | City: karratha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=karratha
# Processing record #38 | City: sassandra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=sassandra
# Processing record #39 | City: saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=saskylakh
# Processing record #40 | City: albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=albany
# Processing record #41 | City: cabo+san+lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=cabo+san+lucas
# Processing record #42 | City: tekirdag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=tekirdag
# Processing record #43 | City: rocha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=rocha
# Processing record #44 | City: sinnamary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=sinnamary
# Processing record #45 | City: havoysund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=havoysund
# Processing record #46 | City: bosaso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bosaso
# Processing record #47 | City: dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=dikson
# Processing record #48 | City: castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=castro
# Processing record #49 | City: coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=coquimbo
# Processing record #50 | City: atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=atuona
# Processing record #51 | City: punta+arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=punta+arenas
# Processing record #52 | City: harper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=harper
# Weather data not found for naugarzan...skipping.
# Error raised: 'main'
# Weather data not found for tatawin...skipping.
# Error raised: 'main'
# Weather data not found for mahaicony...skipping.
# Error raised: 'main'
# Processing record #53 | City: hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=hilo
# Processing record #54 | City: kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kapaa
# Processing record #55 | City: georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=georgetown
# Weather data not found for belushya+guba...skipping.
# Error raised: 'main'
# Processing record #56 | City: vila+franca+do+campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=vila+franca+do+campo
# Processing record #57 | City: san+vicente
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=san+vicente
# Processing record #58 | City: touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=touros
# Processing record #59 | City: bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bethel
# Processing record #60 | City: almunecar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=almunecar
# Processing record #61 | City: beloha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=beloha
# Processing record #62 | City: naryan-mar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=naryan-mar
# Processing record #63 | City: lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=lebu
# Processing record #64 | City: chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=chuy
# Processing record #65 | City: ponta+do+sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ponta+do+sol
# Processing record #66 | City: fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=fortuna
# Processing record #67 | City: avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=avarua
# Processing record #68 | City: ampanihy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ampanihy
# Processing record #69 | City: svetlaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=svetlaya
# Processing record #70 | City: palmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=palmer
# Processing record #71 | City: carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=carnarvon
# Weather data not found for toliary...skipping.
# Error raised: 'main'
# Processing record #72 | City: sioux+lookout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=sioux+lookout
# Processing record #73 | City: houma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=houma
# Processing record #74 | City: kysyl-syr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kysyl-syr
# Processing record #75 | City: myaundzha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=myaundzha
# Processing record #76 | City: kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kaitangata
# Processing record #77 | City: norman+wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=norman+wells
# Processing record #78 | City: yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=yellowknife
# Processing record #79 | City: ternate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ternate
# Processing record #80 | City: yavatmal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=yavatmal
# Processing record #81 | City: la+grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=la+grande
# Processing record #82 | City: new+norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=new+norfolk
# Processing record #83 | City: chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=chokurdakh
# Weather data not found for fort+saint+john...skipping.
# Error raised: 'main'
# Processing record #84 | City: ulladulla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ulladulla
# Weather data not found for armacao+dos+buzios...skipping.
# Error raised: 'main'
# Processing record #85 | City: shache
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=shache
# Processing record #86 | City: port+blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=port+blair
# Processing record #87 | City: khandyga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=khandyga
# Processing record #88 | City: jiwani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=jiwani
# Processing record #89 | City: kutum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kutum
# Weather data not found for grand+river+south+east...skipping.
# Error raised: 'main'
# Processing record #90 | City: adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=adrar
# Processing record #91 | City: thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=thompson
# Processing record #92 | City: bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bluff
# Processing record #93 | City: waingapu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=waingapu
# Processing record #94 | City: mana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=mana
# Weather data not found for nizhneyansk...skipping.
# Error raised: 'main'
# Processing record #95 | City: chongwe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=chongwe
# Processing record #96 | City: namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=namatanai
# Processing record #97 | City: saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=saldanha
# Processing record #98 | City: bonfim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bonfim
# Processing record #99 | City: veracruz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=veracruz
# Processing record #100 | City: nantucket
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=nantucket
# Processing record #101 | City: iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=iqaluit
# Processing record #102 | City: salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=salalah
# Processing record #103 | City: druzhba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=druzhba
# Processing record #104 | City: rapid+valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=rapid+valley
# Processing record #105 | City: saint+george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=saint+george
# Processing record #106 | City: butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=butaritari
# Processing record #107 | City: cape+town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=cape+town
# Processing record #108 | City: pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=pangnirtung
# Processing record #109 | City: flin+flon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=flin+flon
# Processing record #110 | City: clyde+river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=clyde+river
# Processing record #111 | City: victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=victoria
# Weather data not found for grand+centre...skipping.
# Error raised: 'main'
# Processing record #112 | City: bereznik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bereznik
# Processing record #113 | City: hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=hami
# Processing record #114 | City: egvekinot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=egvekinot
# Processing record #115 | City: gimli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=gimli
# Processing record #116 | City: vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=vaini
# Processing record #117 | City: lasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=lasa
# Processing record #118 | City: abha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=abha
# Processing record #119 | City: tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=tasiilaq
# Processing record #120 | City: blyznyuky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=blyznyuky
# Processing record #121 | City: tsnori
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=tsnori
# Processing record #122 | City: portknockie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=portknockie
# Processing record #123 | City: geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=geraldton
# Processing record #124 | City: hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=hasaki
# Processing record #125 | City: nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=nikolskoye
# Processing record #126 | City: lisakovsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=lisakovsk
# Processing record #127 | City: prieska
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=prieska
# Processing record #128 | City: moyale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=moyale
# Processing record #129 | City: colares
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=colares
# Weather data not found for achisay...skipping.
# Error raised: 'main'
# Processing record #130 | City: kiruna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kiruna
# Processing record #131 | City: hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=hobyo
# Processing record #132 | City: tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=tuktoyaktuk
# Processing record #133 | City: fort+nelson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=fort+nelson
# Weather data not found for taolanaro...skipping.
# Error raised: 'main'
# Processing record #134 | City: chagoda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=chagoda
# Processing record #135 | City: mar+del+plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=mar+del+plata
# Weather data not found for nguiu...skipping.
# Error raised: 'main'
# Processing record #136 | City: meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=meulaboh
# Processing record #137 | City: olinda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=olinda
# Processing record #138 | City: aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=aklavik
# Processing record #139 | City: chapais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=chapais
# Weather data not found for umzimvubu...skipping.
# Error raised: 'main'
# Processing record #140 | City: rio+gallegos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=rio+gallegos
# Processing record #141 | City: maloy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=maloy
# Processing record #142 | City: vilyuysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=vilyuysk
# Weather data not found for ndele...skipping.
# Error raised: 'main'
# Processing record #143 | City: jiangyou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=jiangyou
# Processing record #144 | City: sola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=sola
# Processing record #145 | City: nicoya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=nicoya
# Processing record #146 | City: edgewater
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=edgewater
# Processing record #147 | City: arraial+do+cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=arraial+do+cabo
# Weather data not found for lawan+kuda+baharu...skipping.
# Error raised: 'main'
# Processing record #148 | City: villarrica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=villarrica
# Processing record #149 | City: dali
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=dali
# Processing record #150 | City: east+london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=east+london
# Processing record #151 | City: dakoro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=dakoro
# Processing record #152 | City: matara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=matara
# Processing record #153 | City: rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=rawson
# Processing record #154 | City: dicabisagan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=dicabisagan
# Processing record #155 | City: esqueda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=esqueda
# Processing record #156 | City: port+moresby
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=port+moresby
# Processing record #157 | City: nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=nanortalik
# Processing record #158 | City: gazojak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=gazojak
# Processing record #159 | City: belaya+gora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=belaya+gora
# Processing record #160 | City: banda+aceh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=banda+aceh
# Processing record #161 | City: virovitica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=virovitica
# Processing record #162 | City: roma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=roma
# Processing record #163 | City: sangueya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=sangueya
# Processing record #164 | City: darhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=darhan
# Weather data not found for sinkat...skipping.
# Error raised: 'main'
# Processing record #165 | City: san+policarpo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=san+policarpo
# Processing record #166 | City: kaniama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kaniama
# Processing record #167 | City: esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=esperance
# Processing record #168 | City: poopo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=poopo
# Processing record #169 | City: filadelfia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=filadelfia
# Processing record #170 | City: upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=upernavik
# Processing record #171 | City: bingol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bingol
# Processing record #172 | City: la+cruz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=la+cruz
# Processing record #173 | City: hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=hamilton
# Processing record #174 | City: komsomolets
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=komsomolets
# Processing record #175 | City: airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=airai
# Processing record #176 | City: taltal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=taltal
# Processing record #177 | City: caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=caravelas
# Processing record #178 | City: khanpur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=khanpur
# Processing record #179 | City: bintulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bintulu
# Processing record #180 | City: bria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bria
# Processing record #181 | City: bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bathsheba
# Processing record #182 | City: mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=mitsamiouli
# Processing record #183 | City: mogadishu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=mogadishu
# Processing record #184 | City: westport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=westport
# Processing record #185 | City: necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=necochea
# Processing record #186 | City: kiunga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kiunga
# Processing record #187 | City: pictou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=pictou
# Processing record #188 | City: bichura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bichura
# Processing record #189 | City: saint-joseph
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=saint-joseph
# Processing record #190 | City: fort+frances
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=fort+frances
# Processing record #191 | City: almirante
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=almirante
# Processing record #192 | City: khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=khatanga
# Processing record #193 | City: hualmay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=hualmay
# Weather data not found for vaitupu...skipping.
# Error raised: 'main'
# Processing record #194 | City: agadez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=agadez
# Processing record #195 | City: soyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=soyo
# Processing record #196 | City: komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=komsomolskiy
# Processing record #197 | City: nurota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=nurota
# Processing record #198 | City: saint-paul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=saint-paul
# Processing record #199 | City: whitehorse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=whitehorse
# Processing record #200 | City: bambous+virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bambous+virieux
# Processing record #201 | City: alyangula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=alyangula
# Processing record #202 | City: narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=narsaq
# Weather data not found for asfi...skipping.
# Error raised: 'main'
# Processing record #203 | City: terney
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=terney
# Processing record #204 | City: te+anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=te+anau
# Processing record #205 | City: goderich
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=goderich
# Processing record #206 | City: dalbandin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=dalbandin
# Processing record #207 | City: guatire
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=guatire
# Processing record #208 | City: yermish
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=yermish
# Processing record #209 | City: vila+velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=vila+velha
# Processing record #210 | City: kangaatsiaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kangaatsiaq
# Processing record #211 | City: algeciras
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=algeciras
# Processing record #212 | City: broken+hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=broken+hill
# Processing record #213 | City: vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=vao
# Processing record #214 | City: san+andres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=san+andres
# Processing record #215 | City: richards+bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=richards+bay
# Processing record #216 | City: camamu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=camamu
# Processing record #217 | City: srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=srednekolymsk
# Processing record #218 | City: boyolangu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=boyolangu
# Processing record #219 | City: jimeta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=jimeta
# Weather data not found for wahran...skipping.
# Error raised: 'main'
# Processing record #220 | City: sungaipenuh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=sungaipenuh
# Processing record #221 | City: saint-leu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=saint-leu
# Processing record #222 | City: teknaf
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=teknaf
# Weather data not found for vicuna...skipping.
# Error raised: 'main'
# Weather data not found for tabialan...skipping.
# Error raised: 'main'
# Processing record #223 | City: tocopilla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=tocopilla
# Processing record #224 | City: acapulco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=acapulco
# Weather data not found for kamenskoye...skipping.
# Error raised: 'main'
# Processing record #225 | City: youkounkoun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=youkounkoun
# Processing record #226 | City: talcahuano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=talcahuano
# Processing record #227 | City: leshukonskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=leshukonskoye
# Processing record #228 | City: tigil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=tigil
# Processing record #229 | City: weligama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=weligama
# Processing record #230 | City: praia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=praia
# Processing record #231 | City: san+patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=san+patricio
# Processing record #232 | City: miri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=miri
# Processing record #233 | City: sao+filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=sao+filipe
# Processing record #234 | City: narasannapeta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=narasannapeta
# Processing record #235 | City: zyryanka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=zyryanka
# Processing record #236 | City: gazanjyk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=gazanjyk
# Processing record #237 | City: agirish
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=agirish
# Processing record #238 | City: akdepe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=akdepe
# Processing record #239 | City: kroya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kroya
# Processing record #240 | City: ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ancud
# Processing record #241 | City: pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=pisco
# Processing record #242 | City: natitingou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=natitingou
# Processing record #243 | City: burnie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=burnie
# Processing record #244 | City: lira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=lira
# Processing record #245 | City: ambon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ambon
# Weather data not found for bengkulu...skipping.
# Error raised: 'main'
# Processing record #246 | City: paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=paamiut
# Processing record #247 | City: iglino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=iglino
# Weather data not found for tarudant...skipping.
# Error raised: 'main'
# Processing record #248 | City: mount+isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=mount+isa
# Processing record #249 | City: faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=faanui
# Processing record #250 | City: marystown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=marystown
# Processing record #251 | City: hagi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=hagi
# Processing record #252 | City: jega
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=jega
# Processing record #253 | City: peruibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=peruibe
# Processing record #254 | City: lebanon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=lebanon
# Processing record #255 | City: sinegorye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=sinegorye
# Processing record #256 | City: katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=katsuura
# Processing record #257 | City: los+llanos+de+aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=los+llanos+de+aridane
# Processing record #258 | City: tura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=tura
# Processing record #259 | City: chicama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=chicama
# Processing record #260 | City: clermont
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=clermont
# Processing record #261 | City: yenagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=yenagoa
# Processing record #262 | City: tombouctou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=tombouctou
# Weather data not found for meyungs...skipping.
# Error raised: 'main'
# Weather data not found for wa...skipping.
# Error raised: 'main'
# Processing record #263 | City: naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=naze
# Processing record #264 | City: avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=avera
# Processing record #265 | City: shuyskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=shuyskoye
# Processing record #266 | City: monrovia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=monrovia
# Processing record #267 | City: igrim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=igrim
# Processing record #268 | City: cairns
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=cairns
# Processing record #269 | City: wuwei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=wuwei
# Processing record #270 | City: zhigansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=zhigansk
# Processing record #271 | City: wamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=wamba
# Processing record #272 | City: lages
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=lages
# Processing record #273 | City: san+jose
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=san+jose
# Processing record #274 | City: kaka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kaka
# Processing record #275 | City: puerto+escondido
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=puerto+escondido
# Processing record #276 | City: pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=pevek
# Processing record #277 | City: moose+factory
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=moose+factory
# Processing record #278 | City: oblivskaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=oblivskaya
# Processing record #279 | City: rumoi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=rumoi
# Processing record #280 | City: half+moon+bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=half+moon+bay
# Processing record #281 | City: valparaiso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=valparaiso
# Processing record #282 | City: ust-nera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ust-nera
# Processing record #283 | City: roald
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=roald
# Processing record #284 | City: limbang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=limbang
# Processing record #285 | City: oranjemund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=oranjemund
# Weather data not found for palabuhanratu...skipping.
# Error raised: 'main'
# Processing record #286 | City: codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=codrington
# Weather data not found for karkaralinsk...skipping.
# Error raised: 'main'
# Weather data not found for skalistyy...skipping.
# Error raised: 'main'
# Processing record #287 | City: ola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ola
# Processing record #288 | City: vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=vestmannaeyjar
# Processing record #289 | City: tecoanapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=tecoanapa
# Processing record #290 | City: klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=klaksvik
# Processing record #291 | City: lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=lagoa
# Weather data not found for aflu...skipping.
# Error raised: 'main'
# Processing record #292 | City: berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=berlevag
# Processing record #293 | City: marienburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=marienburg
# Weather data not found for ijaki...skipping.
# Error raised: 'main'
# Processing record #294 | City: kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kavieng
# Processing record #295 | City: coos+bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=coos+bay
# Processing record #296 | City: palauig
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=palauig
# Processing record #297 | City: khandbari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=khandbari
# Processing record #298 | City: brignoles
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=brignoles
# Processing record #299 | City: kamaishi
# ...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=luanda
# Processing record #407 | City: ryotsu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ryotsu
# Processing record #408 | City: marsa+matruh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=marsa+matruh
# Processing record #409 | City: harda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=harda
# Weather data not found for saleaula...skipping.
# Error raised: 'main'
# Weather data not found for qui+nhon...skipping.
# Error raised: 'main'
# Weather data not found for uzumlu...skipping.
# Error raised: 'main'
# Processing record #410 | City: beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=beringovskiy
# Processing record #411 | City: phan+thiet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=phan+thiet
# Processing record #412 | City: kaeo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kaeo
# Weather data not found for tulagi...skipping.
# Error raised: 'main'
# Processing record #413 | City: kalmunai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kalmunai
# Processing record #414 | City: zelenogradsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=zelenogradsk
# Weather data not found for haibowan...skipping.
# Error raised: 'main'
# Processing record #415 | City: port+shepstone
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=port+shepstone
# Processing record #416 | City: omsukchan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=omsukchan
# Processing record #417 | City: tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=tautira
# Processing record #418 | City: najran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=najran
# Processing record #419 | City: birao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=birao
# Processing record #420 | City: puerto+baquerizo+moreno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=puerto+baquerizo+moreno
# Processing record #421 | City: anuradhapura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=anuradhapura
# Processing record #422 | City: severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=severo-kurilsk
# Processing record #423 | City: bambanglipuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bambanglipuro
# Processing record #424 | City: robstown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=robstown
# Processing record #425 | City: lazaro+cardenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=lazaro+cardenas
# Processing record #426 | City: borogontsy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=borogontsy
# Processing record #427 | City: ordynskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ordynskoye
# Weather data not found for espana...skipping.
# Error raised: 'main'
# Processing record #428 | City: kinablangan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kinablangan
# Processing record #429 | City: vierzon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=vierzon
# Weather data not found for ikole...skipping.
# Error raised: 'main'
# Processing record #430 | City: uyuni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=uyuni
# Processing record #431 | City: tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=tuatapere
# Processing record #432 | City: ribeira+grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ribeira+grande
# Processing record #433 | City: nelson+bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=nelson+bay
# Processing record #434 | City: kuryk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kuryk
# Processing record #435 | City: amahai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=amahai
# Processing record #436 | City: kupang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kupang
# Processing record #437 | City: las+vegas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=las+vegas
# Processing record #438 | City: alakurtti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=alakurtti
# Processing record #439 | City: kalengwa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kalengwa
# Processing record #440 | City: sibu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=sibu
# Processing record #441 | City: rodeo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=rodeo
# Weather data not found for cockburn+harbour...skipping.
# Error raised: 'main'
# Processing record #442 | City: roebourne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=roebourne
# Processing record #443 | City: greenwood
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=greenwood
# Processing record #444 | City: morant+bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=morant+bay
# Processing record #445 | City: innisfail
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=innisfail
# Weather data not found for tabiauea...skipping.
# Error raised: 'main'
# Processing record #446 | City: the+valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=the+valley
# Processing record #447 | City: faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=faya
# Processing record #448 | City: halifax
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=halifax
# Processing record #449 | City: campanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=campanha
# Processing record #450 | City: aztec
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=aztec
# Processing record #451 | City: labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=labuhan
# Processing record #452 | City: hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=hambantota
# Processing record #453 | City: kuldur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kuldur
# Processing record #454 | City: kamyshin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kamyshin
# Processing record #455 | City: puerto+del+rosario
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=puerto+del+rosario
# Processing record #456 | City: panguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=panguna
# Processing record #457 | City: lufilufi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=lufilufi
# Processing record #458 | City: usinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=usinsk
# Processing record #459 | City: tshikapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=tshikapa
# Processing record #460 | City: lapusnicu+mare
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=lapusnicu+mare
# Processing record #461 | City: tokmak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=tokmak
# Processing record #462 | City: husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=husavik
# Processing record #463 | City: bassano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bassano
# Processing record #464 | City: peschanokopskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=peschanokopskoye
# Processing record #465 | City: ereymentau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ereymentau
# Processing record #466 | City: balestrand
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=balestrand
# Processing record #467 | City: berezovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=berezovka
# Processing record #468 | City: sangar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=sangar
# Processing record #469 | City: tazovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=tazovskiy
# Processing record #470 | City: viedma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=viedma
# Processing record #471 | City: yar-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=yar-sale
# Processing record #472 | City: djibo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=djibo
# Processing record #473 | City: mwanza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=mwanza
# Processing record #474 | City: pinawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=pinawa
# Processing record #475 | City: kloulklubed
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kloulklubed
# Processing record #476 | City: cap+malheureux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=cap+malheureux
# Processing record #477 | City: novyy+urengoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=novyy+urengoy
# Processing record #478 | City: lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=lorengau
# Processing record #479 | City: bensonville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bensonville
# Processing record #480 | City: rach+gia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=rach+gia
# Processing record #481 | City: campoverde
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=campoverde
# Processing record #482 | City: berberati
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=berberati
# Processing record #483 | City: odienne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=odienne
# Processing record #484 | City: kununurra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kununurra
# Processing record #485 | City: umm+kaddadah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=umm+kaddadah
# Processing record #486 | City: isla+vista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=isla+vista
# Processing record #487 | City: camopi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=camopi
# Processing record #488 | City: mragowo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=mragowo
# Processing record #489 | City: kirs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kirs
# Processing record #490 | City: vanimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=vanimo
# Processing record #491 | City: dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=dingle
# Processing record #492 | City: dongzhen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=dongzhen
# Processing record #493 | City: pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=pierre
# Processing record #494 | City: zaysan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=zaysan
# Processing record #495 | City: qandala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=qandala
# Processing record #496 | City: nuuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=nuuk
# Processing record #497 | City: basco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=basco
# Processing record #498 | City: balkanabat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=balkanabat
# Processing record #499 | City: petrovskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=petrovskoye
# Processing record #500 | City: rundu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=rundu
# Processing record #501 | City: chulym
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=chulym
# Processing record #502 | City: lodja
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=lodja
# Processing record #503 | City: verkhnyaya+toyma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=verkhnyaya+toyma
# Processing record #504 | City: sharon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=sharon
# Processing record #505 | City: awbari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=awbari
#
# -------------------------
# Data retrieval complete!
# -------------------------

# %%
# Checking that lists are of equal lengths
print(len(temp))
print(len(humidity))
print(len(cloudiness))
print(len(wind_speed))
print(len(cities))
print(len(used_cities))
# Out:
# 505
# 505
# 505
# 505
# 560
# 505

# %%
print(len(lats))
# Out:
# 505

# %%
weather_dict = {
    "city": used_cities,
    "latitude": lats,
    "temp": temp,
    "humidity (%)": humidity,
    "cloudiness (%)": cloudiness,
    "wind speed (mph)": wind_speed
    
}
weather_data = pd.DataFrame(weather_dict)
weather_data.head(10)
# Out:
#           city  latitude   temp  humidity (%)  cloudiness (%)  \
# 0     la+ronge     55.10  59.00            82              20
# 1  port+alfred    -33.59  51.99           100               0
# 2    busselton    -33.64  60.81           100              76
# 3    hithadhoo     -0.60  81.51           100              20
# 4      margate    -43.03  55.40            50              75
# 5      qaanaaq     77.48  40.65            83              64
# 6    jamestown    -33.21  45.33            97              92
# 7       torbay     47.66  53.60            93              90
# 8        tiksi     71.64  52.17            75               0
# 9       namibe    -15.19  64.23           100               0
#
#    wind speed (mph)
# 0              5.82
# 1              5.86
# 2             16.49
# 3             10.78
# 4             11.41
# 5             12.57
# 6             17.60
# 7             12.75
# 8             11.45
# 9             13.58

# %%
plt.scatter(weather_data['latitude'], weather_data['humidity (%)'])
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title('City Latitude vs Humidity (8/5/2018)')
plt.savefig('latvshum.png')

# %%
plt.scatter(weather_data['latitude'], weather_data['temp'])
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.title('City Latitude vs Temperature (8/5/2018)')
plt.xlim(-80,100)
plt.ylim(-20, 120)
plt.savefig('latvstemp.png')

# %%
plt.scatter(weather_data['latitude'], weather_data['cloudiness (%)'])
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title('City Latitude vs Cloudiness (%) (8/5/2018)')
plt.xlim(-80,100)
plt.ylim(-20, 120)
plt.savefig('latvscloud.png')

# %%
plt.scatter(weather_data['latitude'], weather_data['wind speed (mph)'])
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title('City Latitude vs Wind Speed (%) (8/5/2018)')
plt.xlim(-80,100)
plt.ylim(-5, 40)
plt.savefig('latvswindspeed.png')
